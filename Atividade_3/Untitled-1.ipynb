# %%
import pandas as pd
import openpyxl

# %%
df_raw = pd.read_excel(r'H:\Python\3_Etapa\Atividade_3\Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx', header=2)

# %%
df_raw
# Out:
#                          Unnamed: 0       Total      Homens    Mulheres  \
# 0                            Brasil  25854291.0  10478534.0  15375757.0
# 1                             Norte   1525166.0    590558.0    934609.0
# 2                          Nordeste   4748933.0   1744994.0   3003939.0
# 3                           Sudeste  12828829.0   5391638.0   7437191.0
# 4                               Sul   4338861.0   1768855.0   2570005.0
# 5                      Centro-Oeste   2412502.0    982489.0   1430013.0
# 6                          Rondônia    164632.0     62766.0    101866.0
# 7                              Acre     84300.0     33291.0     51009.0
# 8                          Amazonas    342566.0    141059.0    201507.0
# 9                           Roraima     67045.0     25585.0     41460.0
# 10                             Pará    601096.0    229285.0    371811.0
# 11                            Amapá     89191.0     35085.0     54106.0
# ...

# %%
df_geral = df_raw.iloc[0:33,0:4]

# %%
df_geral = df_geral.rename(columns={"Unnamed: 0": "Regiao"})

# %%
df_geral
# Out:
#                  Regiao       Total      Homens    Mulheres
# 0                Brasil  25854291.0  10478534.0  15375757.0
# 1                 Norte   1525166.0    590558.0    934609.0
# 2              Nordeste   4748933.0   1744994.0   3003939.0
# 3               Sudeste  12828829.0   5391638.0   7437191.0
# 4                   Sul   4338861.0   1768855.0   2570005.0
# 5          Centro-Oeste   2412502.0    982489.0   1430013.0
# 6              Rondônia    164632.0     62766.0    101866.0
# 7                  Acre     84300.0     33291.0     51009.0
# 8              Amazonas    342566.0    141059.0    201507.0
# 9               Roraima     67045.0     25585.0     41460.0
# 10                 Pará    601096.0    229285.0    371811.0
# 11                Amapá     89191.0     35085.0     54106.0
# 12            Tocantins    176336.0     63485.0    112851.0
# 13             Maranhão    468681.0    161352.0    307329.0
# 14                Piauí    304955.0    108371.0    196584.0
# ...

# %%
df_geral.to_excel(r"H:\Python\3_Etapa\Atividade_3\Tabela_3_geral.xlsx")

# %%
df_A = df_raw.iloc[0:33,4:7]

# %%
df_A = df_A.rename(columns={"Homens.1": "Homens"})

# %%
df_A = df_A.rename(columns={"Mulheres.1": "Mulheres"})

# %%
df_A = df_A.rename(columns={"Total.1": "Total"})

# %%
df_A
# Out:
#         Total     Homens   Mulheres
# 0   4149041.0  2750422.0  1398619.0
# 1    209657.0   133055.0    76601.0
# 2    621388.0   389993.0   231395.0
# 3   2328122.0  1588874.0   739247.0
# 4    662916.0   427372.0   235543.0
# 5    326959.0   211124.0   115834.0
# 6     20538.0    11863.0     8675.0
# 7     10364.0     6237.0     4128.0
# 8     52669.0    34749.0    17919.0
# 9      8016.0     4958.0     3057.0
# 10    86691.0    55481.0    31211.0
# 11    11349.0     7464.0     3885.0
# 12    20028.0    12304.0     7724.0
# 13    55068.0    33820.0    21248.0
# 14    37135.0    21668.0    15467.0
# 15    99062.0    63935.0    35126.0
# 16    46857.0    30398.0    16459.0
# 17    52223.0    33369.0    18855.0
# 18   120260.0    73253.0    47007.0
# 19    33596.0    21398.0    12198.0
# 20    29020.0    17596.0    11422.0
# 21   148167.0    94556.0    53612.0
# 22   452258.0   291778.0   160479.0
# 23    75667.0    49648.0    26018.0
# 24   406529.0   265723.0   140805.0
# ...

# %%
df_A.to_excel(r"H:\Python\3_Etapa\Atividade_3\Tabela_3_A.xlsx")

# %%
df_B = df_raw.iloc[0:33,7:10]

# %%
df_B = df_B.rename(columns={"Homens.2": "Homens"})

# %%
df_B = df_B.rename(columns={"Mulheres.2": "Mulheres"})

# %%
df_B = df_B.rename(columns={"Total.2": "Total"})

# %%
df_B
# Out:
#         Total     Homens   Mulheres
# 0   8079707.0  1677985.0  6401723.0
# 1    599785.0   141169.0   458616.0
# 2   1822087.0   363905.0  1458181.0
# 3   3652397.0   768288.0  2884108.0
# 4   1256291.0   248574.0  1007718.0
# 5    749148.0   156048.0   593101.0
# 6     63584.0    13963.0    49622.0
# 7     33379.0     9121.0    24258.0
# 8    121988.0    30738.0    91249.0
# 9     23977.0     5880.0    18098.0
# 10   248397.0    58128.0   190270.0
# 11    36754.0     9794.0    26960.0
# 12    71705.0    13548.0    58158.0
# 13   206222.0    40667.0   165555.0
# 14   128416.0    25959.0   102457.0
# 15   294578.0    64582.0   229996.0
# 16   135434.0    28273.0   107161.0
# 17   150862.0    30025.0   120837.0
# 18   281695.0    57333.0   224362.0
# 19   106971.0    20060.0    86911.0
# 20    83176.0    16801.0    66376.0
# 21   434735.0    80208.0   354528.0
# 22   832482.0   157960.0   674521.0
# 23   161332.0    29788.0   131544.0
# 24   612263.0   145864.0   466399.0
# ...

# %%
df_B.to_excel(r"H:\Python\3_Etapa\Atividade_3\Tabela_3_B.xlsx")
